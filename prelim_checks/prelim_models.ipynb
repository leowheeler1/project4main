# %%
import pandas as pd

# %%
test_df = pd.read_csv("symptom-disease-test-dataset.csv")

# %%
test_df.head()
# Out:
#                                                 text  label
# 0  itching,vomiting,fatigue,weight_loss,high_feve...    541
# 1  fatigue,weight_loss,restlessness,sweating,diar...    502
# 2  constipation,pain_during_bowel_movements,pain_...    297
# 3  chills,vomiting,fatigue,weight_loss,cough,high...   1019
# 4  vomiting,yellowish_skin,abdominal_pain,swellin...     33

# %%
train_df = pd.read_csv("symptom-disease-train-dataset.csv")

# %%
train_df.head()
# Out:
#                                                 text  label
# 0  I have been having migraines and headaches. I ...    308
# 1  I have asthma and I get wheezing and breathing...     35
# 2  Signs and symptoms of primary ovarian insuffic...    798
# 3  cough,high_fever,breathlessness,family_history...    149
# 4  chills,vomiting,high_fever,sweating,headache,n...    596

# %%
X_test = test_df["text"]

# %%
X_train = train_df["text"]

# %%
y_test = test_df["label"]

# %%
y_train = train_df["label"]

# %%
# Import the LogisticRegression module from SKLearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import Ridge
from sklearn.pipeline import Pipeline

# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
lrm = Pipeline([
    ("tfidf", TfidfVectorizer()),
    ("regressor", Ridge())
])

# Fit the model using training data
lrm.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('regressor', Ridge())])

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Make a prediction using the testing data
predictions = lrm.predict(X_test)

# %%
# Print the classification report for the model
print(classification_report(y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Print the classification report for the model
# ----> 2 print(classification_report(y_test, predictions))
#
# File ~\anaconda3\envs\dev\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
# ...

# %%
user_input1 = "my stomach hurts and I can't sleep"
prediction1 = lrm.predict([user_input1])

# %%
print(prediction1)
# Out:
# [786.54939859]

# %%
user_input2 = "i can't stop thinking about grilled cheese sandwiches"
prediction2 = lrm.predict([user_input2])
print(prediction2)
# Out:
# [557.16043539]

# %%
user_input3 = "i feel healthy"
prediction3 = lrm.predict([user_input3])
print(prediction3)
# Out:
# [409.25193717]

# %%
user_input4 = "i've never felt better"
prediction4 = lrm.predict([user_input4])
print(prediction4)
# Out:
# [441.3577911]

# %%
from sklearn.ensemble import RandomForestRegressor

rfmodel = Pipeline([
    ("tfidf", TfidfVectorizer()),
    ("regressor", RandomForestRegressor(n_estimators=100, random_state=1))
])
# Fit the model using training data
rfmodel.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('regressor', RandomForestRegressor(random_state=1))])

# %%
user_input1_1 = "my stomach hurts and I can't sleep"
prediction1_1 = rfmodel.predict([user_input1_1])
print(prediction1_1)
# Out:
# [545.78]

# %%
user_input2_1 = "i can't stop thinking about grilled cheese sandwiches"
prediction2_1 = rfmodel.predict([user_input2_1])
print(prediction2_1)
# Out:
# [242.66]

# %%
user_input3_1 = "i feel healthy"
prediction3_1 = rfmodel.predict([user_input3_1])
print(prediction3_1)
# Out:
# [232.15]

# %%
user_input4_1 = "i've never felt better"
prediction4_1 = rfmodel.predict([user_input4_1])
print(prediction4_1)
# Out:
# [282.83]

# %%
user_input5_1 = "my stomach hurts, i'm bleeding and seeing stars"
prediction5_1 = rfmodel.predict([user_input5_1])
print(prediction5_1)
# Out:
# [593.61]

# %%
user_input6_1 = "i have a fever, can't see straight and don't remember my name"
prediction6_1 = rfmodel.predict([user_input6_1])
print(prediction6_1)
# Out:
# [288.]
